# %%
#Aditya Sivaram
#PES1201700012
#Krishnamoorthy M
#PES1201700636

# %%
nltk.download()
# Out:
# showing info https://raw.githubusercontent.com/nltk/nltk_data/gh-pages/index.xml
# True

# %%
#Part 1

# %%
import nltk
from nltk.stem import *
from nltk.corpus import stopwords 
from nltk.corpus import inaugural
from nltk.tokenize import word_tokenize, sent_tokenize
nltk.download('inaugural')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package inaugural to C:\Users\ADITYA
# [nltk_data]     SIVARAM\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\ADITYA
# [nltk_data]     SIVARAM\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
names=inaugural.fileids()
print(len(names))
names[0],names[55]
# Out:
# 58
# ('1789-Washington.txt', '2009-Obama.txt')

# %%
#Task A

text51=""+inaugural.raw(fileids=names[51])+inaugural.raw(fileids=names[52])+inaugural.raw(fileids=names[53])+inaugural.raw(fileids=names[54])+inaugural.raw(fileids=names[55])
text51=str(text51)
print(text51)
print(" ")

#Task B

stk51=sent_tokenize(text51)
print(stk51)
#print(text51)
# Out:
# My fellow citizens, today we celebrate the mystery of American renewal. This ceremony is held in the depth of winter, but by the words we speak and the faces we show the world, we force the spring. A spring reborn in the world's oldest democracy, that brings forth the vision and courage to reinvent America. When our founders boldly declared America's independence to the world, and our purposes to the Almighty, they knew that America, to endure, would have to change. Not change for change sake, but change to preserve America's ideals: life, liberty, the pursuit of happiness.
#
# Though we march to the music of our time, our mission is timeless. Each generation of American's must define what it means to be an American. On behalf of our nation, I salute my predecessor, President Bush, for his half-century of service to America and I thank the millions of men and women whose steadfastness and sacrifice triumphed over depression, fascism and communism.
#
# ...

# %%
#Task C

for w in stk51:
    w51=word_tokenize(w)
    print(w51)
# Out:
# ['My', 'fellow', 'citizens', ',', 'today', 'we', 'celebrate', 'the', 'mystery', 'of', 'American', 'renewal', '.']
# ['This', 'ceremony', 'is', 'held', 'in', 'the', 'depth', 'of', 'winter', ',', 'but', 'by', 'the', 'words', 'we', 'speak', 'and', 'the', 'faces', 'we', 'show', 'the', 'world', ',', 'we', 'force', 'the', 'spring', '.']
# ['A', 'spring', 'reborn', 'in', 'the', 'world', "'s", 'oldest', 'democracy', ',', 'that', 'brings', 'forth', 'the', 'vision', 'and', 'courage', 'to', 'reinvent', 'America', '.']
# ['When', 'our', 'founders', 'boldly', 'declared', 'America', "'s", 'independence', 'to', 'the', 'world', ',', 'and', 'our', 'purposes', 'to', 'the', 'Almighty', ',', 'they', 'knew', 'that', 'America', ',', 'to', 'endure', ',', 'would', 'have', 'to', 'change', '.']
# ['Not', 'change', 'for', 'change', 'sake', ',', 'but', 'change', 'to', 'preserve', 'America', "'s", 'ideals', ':', 'life', ',', 'liberty', ',', 'the', 'pursuit', 'of', 'happiness', '.']
# ...

# %%
#Task D

stop_words = set(stopwords.words('english')) 
wtk51=word_tokenize(text51)
stop_51=[]
for w in wtk51:
    if w not in stop_words: 
        stop_51.append(w)
print(stop_51)
print("   ")
ps = PorterStemmer()
stem_51=[]
for z in stop_51:
    z=ps.stem(z)
    stem_51.append(z)
print(stem_51)
# Out:
# ['My', 'fellow', 'citizens', ',', 'today', 'celebrate', 'mystery', 'American', 'renewal', '.', 'This', 'ceremony', 'held', 'depth', 'winter', ',', 'words', 'speak', 'faces', 'show', 'world', ',', 'force', 'spring', '.', 'A', 'spring', 'reborn', 'world', "'s", 'oldest', 'democracy', ',', 'brings', 'forth', 'vision', 'courage', 'reinvent', 'America', '.', 'When', 'founders', 'boldly', 'declared', 'America', "'s", 'independence', 'world', ',', 'purposes', 'Almighty', ',', 'knew', 'America', ',', 'endure', ',', 'would', 'change', '.', 'Not', 'change', 'change', 'sake', ',', 'change', 'preserve', 'America', "'s", 'ideals', ':', 'life', ',', 'liberty', ',', 'pursuit', 'happiness', '.', 'Though', 'march', 'music', 'time', ',', 'mission', 'timeless', '.', 'Each', 'generation', 'American', "'s", 'must', 'define', 'means', 'American', '.', 'On', 'behalf', 'nation', ',', 'I', 'salute', 'predecessor', ',', 'President', 'Bush', ',', 'half-century', 'service', 'America', 'I', 'thank', 'millions', 
# ...

# %%
conda install -c conda-forge wordcloud
# Out:
# Note: you may need to restart the kernel to use updated packages.
# usage: conda-script.py [-h] [-V] command ...
# conda-script.py: error: unrecognized arguments: wordcloud

# %%
#Task F

from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
text=""
for word in stem_51:  
        text = text + " " + word 
wordcloud = WordCloud(width=480, height=480, max_words=10).generate(text) 
plt.figure() 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0) 
plt.show() 

from wordcloud import WordCloud 
import matplotlib.pyplot as plt 
text=""
for word in wtk51:  
        text = text + " " + word 
wordcloud = WordCloud(width=480, height=480, max_words=10).generate(text) 
plt.figure() 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0) 
plt.show()

# %%
#Task G

#Both the word clouds are roughly the same.
#This shows that stemming and removing stop words does not affect the word-clouds

# %%
#Task J

import re
for z in stem_51:
    if(re.search("[0-9]", z)):
        print(z)
for z in stem_51:
    if(re.search("[^a-zA-Z]", z)):
        print(z)
# Out:
# 21st
# 20th
# 18th
# 19th
# 19th
# 20th
# 21st
# 21st
# 20th
# 21st
# 225
# ,
# .
# ,
# ,
# .
# 's
# ,
# .
# 's
# ,
# ,
# ,
# ,
# .
# ,
# 's
# :
# ,
# ,
# .
# ,
# .
# 's
# .
# ,
# ,
# ,
# half-centuri
# ,
# .
# ,
# ,
# .
# ,
# 's
# ,
# ,
# ,
# ,
# .
# ,
# ,
# .
# .
# .
# .
# ,
# .
# .
# ,
# .
# .
# ,
# ,
# ,
# ;
# ;
# ,
# .
# ,
# .
# ,
# ,
# ,
# .
# ,
# .
# ,
# ,
# ,
# .
# ,
# ,
# ,
# .
# .
# ,
# ,
# .
# .
# .
# .
# ,
# .
# .
# .
# ,
# ,
# ,
# .
# .
# ,
# ,
# .
# ,
# .
# .
# .
# .
# 's
# .
# ,
# ,
# ,
# .
# ,
# .
# :
# ,
# .
# ,
# ,
# .
# .
# ,
# ,
# .
# ,
# ,
# .
# ,
# ,
# ,
# ,
# .
# ,
# .
# ``
# ,
# ,
# ,
# .
# ''
# .
# ,
# .
# .
# ,
# ,
# ,
# :
# .
# ,
# ,
# .
# 's
# ,
# .
# ,
# .
# ,
# .
# ,
# ,
# .
# ,
# ,
# ;
# ,
# .
# ,
# ,
# ,
# ,
# ,
# .
# ,
# .
# ,
# ,
# ,
# ,
# .
# 's
# .
# .
# ,
# ,
# ,
# ,
# .
# ,
# ,
# ,
# .
# .
# .
# ;
# ,
# ,
# .
# ,
# ,
# ,
# .
# ,
# ,
# ,
# ,
# .
# .
# ,
# ,
# ,
# ,
# .
# ,
# ,
# :
# ,
# .
# ,
# ,
# ,
# ,
# ,
# ,
# ,
# ;
# ,
# ;
# 's
# ,
# .
# ,
# ...

# %%
#Task I


wl=[]
task=[]
stop_words = set(stopwords.words('english')) 
word_freq=word_tokenize(text51)
for w in word_freq:
    if w not in stop_words:
        wl.append(w)
sent_freq=sent_tokenize(text51)
for each in sent_freq:
    line=each.split()
    sumc=0
    for k in line:
        sumc=sumc+wl.count(k)
    l=[]
    l.append(each)
    l.append(sumc)
    task.append(l)
#print(word_freq)
#print(wl)
task.sort(key=lambda x: -x[1])
for i in range(0,5):
    print(task[[i][0]])
# Out:
# ['We are shaped by every language and culture, drawn from every end of this Earth; and because we have tasted the bitter swill of civil war and segregation, and emerged from that dark chapter stronger and more united, we cannot help but believe that the old hatreds shall someday pass; that the lines of tribe shall soon dissolve; that as the world grows smaller, our common humanity shall reveal itself; and that America must play its role in ushering in a new era of peace.', 459]
# ['We need a new government for a new century -- humble enough not to try to solve all our problems for us, but strong enough to give us the tools to solve our problems for ourselves; a government that is smaller, lives within its means, and does more with less.', 408]
# ...

# %%
#Task H

from nltk import pos_tag, word_tokenize
ps=[]
ps=list(pos_tag(word_tokenize(text51)))
#print(ps)
tags=[]
tags=[["CC",0],["CD",0],["DT",0],["EX",0],["FW",0],["IN",0],["JJ",0],["JJR",0],["JJS",0],["LS",0],["MD",0],["NN",0],["NNS",0],["NNP",0],["NNPS",0],["PDT",0],["POS",0],["PRP",0],["PRP$",0],["RB",0],["RBR",0],["RBS",0],["RP",0],["SYM",0],["TO",0],["UH",0],["VB",0],["VBD",0],["VBG",0],["VBN",0],["VBP",0],["VBZ",0],["WDT",0],["WP",0],["WP$",0],["WRB",0]]
ck=[]
for h in tags:
    ck.append(h[0])

for (a,b) in ps:
    if b in ck:
        v=ck.index(b)
        tags[v][1]=tags[v][1]+1
print(tags)

from wordcloud import WordCloud
import matplotlib.pyplot as plt
wc=""
for g in tags:
    for f in range(0,g[1]):
        wc=wc+" "+g[0]
#print(wc)
wordcloud = WordCloud(width=3000, height=3000, max_words=36,collocations=False).generate(wc) 
#plt.figure() 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0) 
plt.show()
# Out:
# [['CC', 562], ['CD', 29], ['DT', 1049], ['EX', 15], ['FW', 1], ['IN', 1201], ['JJ', 650], ['JJR', 45], ['JJS', 31], ['LS', 0], ['MD', 227], ['NN', 1649], ['NNS', 633], ['NNP', 255], ['NNPS', 41], ['PDT', 15], ['POS', 44], ['PRP', 523], ['PRP$', 406], ['RB', 414], ['RBR', 23], ['RBS', 9], ['RP', 18], ['SYM', 0], ['TO', 266], ['UH', 5], ['VB', 520], ['VBD', 127], ['VBG', 100], ['VBN', 217], ['VBP', 334], ['VBZ', 262], ['WDT', 54], ['WP', 65], ['WP$', 7], ['WRB', 46]]

# %%
####PART 2

# %%
from wordcloud import WordCloud, STOPWORDS 
import matplotlib as plt
import matplotlib.pyplot as plt 
import pandas as pd 
from textblob import TextBlob

# %%
import nltk
from nltk.corpus import inaugural
nltk.download('inaugural')
# Out:
# [nltk_data] Downloading package inaugural to C:\Users\ADITYA
# [nltk_data]     SIVARAM\AppData\Roaming\nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# True

# %%
names=inaugural.fileids()
print(len(names))
names[0],names[55]
text51=""+inaugural.raw(fileids=names[51])+inaugural.raw(fileids=names[52])+inaugural.raw(fileids=names[53])+inaugural.raw(fileids=names[54])+inaugural.raw(fileids=names[55])
text51=str(text51)
print(text51)
print(" ")
# Out:
# 58
# My fellow citizens, today we celebrate the mystery of American renewal. This ceremony is held in the depth of winter, but by the words we speak and the faces we show the world, we force the spring. A spring reborn in the world's oldest democracy, that brings forth the vision and courage to reinvent America. When our founders boldly declared America's independence to the world, and our purposes to the Almighty, they knew that America, to endure, would have to change. Not change for change sake, but change to preserve America's ideals: life, liberty, the pursuit of happiness.
#
# Though we march to the music of our time, our mission is timeless. Each generation of American's must define what it means to be an American. On behalf of our nation, I salute my predecessor, President Bush, for his half-century of service to America and I thank the millions of men and women whose steadfastness and sacrifice triumphed over depression, fascism and communism.
#
# ...

# %%
blobject = TextBlob(text51)

# %%
print(blobject.tags)
# Out:
# [('My', 'PRP$'), ('fellow', 'JJ'), ('citizens', 'NNS'), ('today', 'NN'), ('we', 'PRP'), ('celebrate', 'VBP'), ('the', 'DT'), ('mystery', 'NN'), ('of', 'IN'), ('American', 'JJ'), ('renewal', 'NN'), ('This', 'DT'), ('ceremony', 'NN'), ('is', 'VBZ'), ('held', 'VBN'), ('in', 'IN'), ('the', 'DT'), ('depth', 'NN'), ('of', 'IN'), ('winter', 'NN'), ('but', 'CC'), ('by', 'IN'), ('the', 'DT'), ('words', 'NNS'), ('we', 'PRP'), ('speak', 'VBP'), ('and', 'CC'), ('the', 'DT'), ('faces', 'VBZ'), ('we', 'PRP'), ('show', 'VBP'), ('the', 'DT'), ('world', 'NN'), ('we', 'PRP'), ('force', 'VBP'), ('the', 'DT'), ('spring', 'NN'), ('A', 'DT'), ('spring', 'NN'), ('reborn', 'NN'), ('in', 'IN'), ('the', 'DT'), ('world', 'NN'), ("'s", 'POS'), ('oldest', 'JJS'), ('democracy', 'NN'), ('that', 'WDT'), ('brings', 'VBZ'), ('forth', 'VBZ'), ('the', 'DT'), ('vision', 'NN'), ('and', 'CC'), ('courage', 'NN'), ('to', 'TO'), ('reinvent', 'VB'), ('America', 'NNP'), ('When', 'WRB'), ('our', 'PRP$'), ('founders', 'NNS'), ('
# ...

# %%
nouns = ""
adjs = ""
nounparts = ["NN", "NNS", "NNP", "NNPS"]
adjparts = ["JJ","JJR", "JJS"]
for w in blobject.tags:
    if w[1] in nounparts:
        nouns = nouns + w[0] + " "
    if w[1] in adjparts:
        adjs = adjs + w[0] + " "

# %%
print(nouns)
# Out:
# citizens today mystery renewal ceremony depth winter words world spring spring reborn world democracy vision courage America founders America independence world purposes Almighty America change change sake change America ideals life liberty pursuit happiness music time mission generation American behalf nation predecessor President Bush half-century service America millions men women steadfastness sacrifice depression fascism communism Today generation shadows Cold War responsibilities world sunshine freedom hatreds plagues prosperity economy world business failures wages inequality divisions people George Washington oath news land horseback ocean boat sights sounds ceremony tobillions world Communications commerce Investment Technology ambition life livelihood America today competition people Earth Profound forces world question time friend enemy world lives millions Americans people others cost health care families enterprises fear crime robs law citizens freedom millions children 
# ...

# %%
print(adjs)
# Out:
# fellow American oldest timeless American new ancient new unrivalled strongest stagnant deep own instantaneously global mobile magical better universal peaceful powerful urgent new able most less great small poor hard strong fearsome hopeful very dramatic fellow own wrong right new own same massive easy own own eyes sleep sacred more more bad other more beautiful Powerful better better personal persistent clear foreign domestic old new free stable old new much new international peaceful possible necessary testament greatest new many American unmistakable historic political fellow fellow new troubled torn much young simple powerful other more other myriad deepest heroic fellow 21st weary due joyful own fellow last presidential 20th next great good new new bright new human old young ancient promised new 18th bold equal 19th awful American mightiest industrial long cold great middle old unrivaled public civil African third new 19th 20th free human 21st free global limitless perfect last 
# ...

# %%
##nouns
wordcloud = WordCloud(width=480, height=480, max_words=21).generate(nouns) 
plt.figure() 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0) 
plt.show()

# %%
##adjectives
wordcloud = WordCloud(width=480, height=480, max_words=21).generate(adjs) 
plt.figure() 
plt.imshow(wordcloud, interpolation="bilinear") 
plt.axis("off") 
plt.margins(x=0, y=0) 
plt.show()
